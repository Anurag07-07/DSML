# %% [markdown]
# # OOPS
# ## Object-oriented programming aims to implement real-world entities like inheritance ,hiding,polymorphism ,etc in programming.The main aim of OOP is to bnd together the data and the functions that operate on them so that no other part of the code can access this data except the function
#
# ## Classes and objects are two main aspects of OOPs.
# ## Classes are the user-defined blueprints that help us create an object
# ## Objects are the instances of a particular class

# %%
class Car:
    name = "Maclaren P1"
    color = "Red"
    age = 2

    def describe(self):
        print("The is a car function,Describe cars here.")

# %%
c1 = Car()
c1.describe()
# Out:
# The is a car function,Describe cars here.

# %%
c1

# %%
benz = Car()
benz.name= "Mercedes Benz"
benz.color = "Black"
benz.fuel = "Petrol"
benz.age = 2
print(benz.color,benz.name,benz.fuel,benz.age)
# Out:
# Black Mercedes Benz Petrol 2

# %% [markdown]
# # Create Class Without passing Anything

# %%
class Car:
    pass

# %%
class Car:
    def describe(self):
        print("Car name :",self.name)
        print("Car name :",self.color)
        print("Car name :",self.age)

    def isBanned(self):
        if self.age > 15:
            return True
        else:
            return False

# %%
benz = Car()
benz.name = "Mercedes Benz"
benz.color = "Silver"
benz.age = 2
benz.describe()
# Out:
# Car name : Mercedes Benz
# Car name : Silver
# Car name : 2

# %% [markdown]
# # Constructors

# %%
class Car:
    def __init__(self,name,color,company):
        self.name = name
        self.color = color
        self.company = company

    def describe(self):
        print("Car name :",self.name)
        print("Car name :",self.color)
        print("Car name :",self.company)

# %%
mac = Car("P1","Orange","Maclaren")
mac.describe()
# Out:
# Car name : P1
# Car name : Orange
# Car name : Maclaren

# %% [markdown]
# # Class inside Class

# %%
class Car:
    class Seat:
        def __init__(self,color="grey"):
            self.color = color

    def __init__(self):
        self.name  = "Anurag"

    def drive(self):
        s = self.Seat("Red")
        print(s)

# %%
c1 = Car()
c1.drive()
