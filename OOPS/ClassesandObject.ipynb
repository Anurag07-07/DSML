# %% [markdown]
# # Classes and Objects

# %%
class Car:
  pass

maclaren = Car()
# Out:
# <class '__main__.Car'>
# <__main__.Car object at 0x0000018DFFA4D6D0>

# %%
maclaren.window = 2

print(maclaren.window)
# Out:
# 2

# %%
# Instance Varables and Methods
dir(maclaren)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'window']

# %%
# self == this
# __init__ = constructor 

class Dog:
  def __init__(self,name,age):
    self.name = name
    self.age = age

  def details(self):
    print(self.name,self.age,end=" ")

# %%
dog1 =  Dog("Mary",8)
dog1.details()
# Out:
# Mary 8

# %%
#Modelling a Bank Account
class BankAccount:
  def __init__(self,owner,balance = 0):
    self.owner = owner
    self.balance = balance

  def deposit(self,amount):
    self.balance += amount
    print(f" {amount} is deposited. New balance is {self.balance}")
  
  def withdraw(self,amount):
    if amount>self.balance:
      print("Insufficient Funds!")
    else:
      self.balance -=amount
      print(f"{amount} is withdrawn, New Balance is {self.balance}")

  def get_balance(self):
    return self.balance

# %%
account = BankAccount("someone",5000000000)
print(account.balance)
# Out:
# 5000000000

# %%
account.withdraw(50)
# Out:
# 50 is withdrawn, New Balance is 4999999950

# %%
ans  = account.get_balance()
print(ans)
# Out:
# 4999999950
