# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Simple Interest

# %%
p = 100
r = 5
t = 2
SI = (p*r*t)/100
print("The Simple Interest is",SI)
# Out:
# The Simple Interest is 10.0

# %% [markdown]
# ## Input

# %%
name = input("Enter The Name")

print("Hello",name)
# Out:
# Enter The Name Anurag Rag
# Hello  Anurag Rag

# %%
name1 = input()
name2 = input()
name3 = input()

print("Hello {} {} {}".format(name1,name2,name3))
print(f"Hello {name1} {name2} {name3}")
# Out:
#  Ab
#  Bc
#  Cd
# Hello Ab Bc Cd
# Hello Ab Bc Cd

# %%
message = "Hello Friend\'s Good Morning"
print(message)
# Out:
# Hello Friend's Good Morning

# %% [markdown]
# # Datatype

# %%
a = 100
print(type(a))
# Out:
# <class 'int'>

# %%
b = 10.56223
print(type(b))
# Out:
# <class 'float'>

# %%
c = "Hello"
print(type(c))
d = 'A'
print(type(d))
# Out:
# <class 'str'>
# <class 'str'>

# %%
e = True
print(type(e))
# Out:
# <class 'bool'>

# %%
g = None #No value
print(type(g))
# Out:
# <class 'NoneType'>

# %% [markdown]
# # Typecasting

# %%
#Float to int
a = 100.5
b = int(a)
print(b)

#Int to float
c = 100
d = float(c)
print(d)

e = 456
f = str(e)
print(type(f))
# Out:
# 100
# 100.0
# <class 'str'>

# %%
a = int(float("1.5"))
print(a)
# Out:
# 1

# %%
#Python don't have number range

# %% [markdown]
# # Operator

# %%
a = 5+2
print(a)
b = 5-2
print(b)
c = 5*2
print(c)
d = 5/2 #float
print(d)
e = 5//2 #int
print(e)
f = 5**2
print(f)
g = 5%2
print(g)
h = 4**(1/2)# Square Root
print(h)
# Out:
# 7
# 3
# 10
# 2.5
# 2
# 25
# 1
# 2.0
